# %%
# Coloque a chave do MongoDB na caixinha lateral

# %%
# !pip install pymongo   #- Modo 1
#!python -m pip install pymongo -  Modo 2
# Out:
# Collecting pymongo
#   Downloading pymongo-4.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 5.8 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.5.0-py3-none-any.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.4/305.4 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.5.0 pymongo-4.6.1

# %%
# Abertura de bibliotecas de manipulação e análise
import pandas as pd
import numpy as np

# Abertura de bibliotecas de conectores
import os
from pymongo import MongoClient

# %% [markdown]
# ## **MongoDB**

# %%
"""
COLE SEU CONECTOR AQUI

from pymongo import MongoClient

uri = "mongodb+srv://cluster0.kvilztb.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority"
client = MongoClient(uri,
                     tls=True,
                     tlsCertificateKeyFile='<path_to_certificate>',
                     server_api=ServerApi('1'))

db = client['testDB']
collection = db['testCol']
doc_count = collection.count_documents({})
print(doc_count)
"""
# Out:
# '\nCOLE SEU CONECTOR AQUI\n\nfrom pymongo import MongoClient\n\nuri = "mongodb+srv://cluster0.kvilztb.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority"\nclient = MongoClient(uri,\n                     tls=True,\n                     tlsCertificateKeyFile=\'<path_to_certificate>\',\n                     server_api=ServerApi(\'1\'))\n\ndb = client[\'testDB\']\ncollection = db[\'testCol\']\ndoc_count = collection.count_documents({})\nprint(doc_count)\n'

# %%
# Conector MongoDB
uri = "mongodb+srv://cluster0.kvilztb.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority" # Faça a cópia do Seu CÓDIGO URI
client = MongoClient(uri, tls=True, tlsCertificateKeyFile='/content/X509-cert-5781360384442289393.pem') # Colque SUA CHAVE
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-db32c04a97ab> in <cell line: 3>()
#       1 # Conector MongoDB
#       2 uri = "mongodb+srv://cluster0.kvilztb.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority" # Faça a cópia do Seu CÓDIGO URI
# ----> 3 client = MongoClient(uri, tls=True, tlsCertificateKeyFile='/content/X509-cert-5781360384442289393.pem') # Colque SUA CHAVE
#
# /usr/local/lib/python3.10/dist-packages/pymongo/mongo_client.py in __init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     804         # Validate kwarg options.
#     805         keyword_opts = common._CaseInsensitiveDictionary(
# --> 806             dict(common.validate(keyword_opts.cased_key(k), v) for k, v in keyword_opts.items())
#     807         )
#     808
#
# /usr/local/lib/python3.10/dist-packages/pymongo/mongo_client.py in <genexpr>(.0)
#     804         # Validate kwarg options.
#     805         keyword_opts = common._CaseInsensitiveDictionary(
# --> 806             dict(common.validate(keyword_opts.cased_key(k), v) for k, v in keyword_opts.items())
#     807         )
#     808
#
# /usr/local/lib/python3.10/dist-packages/pymongo/common.py in validate(option, value)
#     819     lower = option.lower()
#     820     validator = VALIDATORS.get(lower, raise_config_error)
# --> 821     value = validator(option, value)
#     822     return option, value
#     823
#
# /usr/local/lib/python3.10/dist-packages/pymongo/common.py in validate_readable(option, value)
#     222     # Used in ssl cert checking due to poor ssl module error reporting
#     223     value = validate_string(option, value)
# --> 224     open(value).close()
#     225     return value
#     226
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/X509-cert-5781360384442289393.pem'

# %%
# Escolhendo a base de dados e coleção
db = client['pandasmongo']
collection = db['brutos']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-eec4ab85485c> in <cell line: 2>()
#       1 # Escolhendo a base de dados e coleção
# ----> 2 db = client['pandasmongo']
#       3 collection = db['brutos']
#
# NameError: name 'client' is not defined

# %%
# Contagem dos documentos - na saída de código tem que dar zero
doc_count = collection.count_documents({})
print(doc_count)
# Out:
# 33845

# %%
# Abertura da base de dados e cópia de segurança (bucket)
df = pd.read_csv(path,
                 sep=';',
                 encoding='ISO-8859-1',
                 dayfirst = True)
dfback = df.copy()

# %%
# Conversão para colocar no MongoDB
df_dict = df.to_dict("records")
collection.insert_many(df_dict)

# %%
# Checagem de valores no MongoDB
collection.count_documents({})

# %%
# Checagem da coleção do MongoDB
for x in collection.find():
  print(x)

# %% [markdown]
# ##**Tratamento**

# %%
path = 'gs://projetos-aula/projeto-cenipa/tratado/cenipa_tratado.csv'
df = pd.read_csv(path,
                 sep=',',
                 encoding='ISO-8859-1',
                 )

# %% [markdown]
# ## **Carregamento**

# %%
# Carregamento no MongoDB
db2 = client['pandasmongo']
collection2 = db2['tratados']
collection2.count_documents({})

# %%
# Conversão de dados para MongoDB
df_dict = df.to_dict("records")
collection2.insert_many(df_dict)

# %%
# Contagem de dados: verificação
collection2.count_documents({})

# %%
# Checagem da coleção
for x in collection2.find():
  print(x)
