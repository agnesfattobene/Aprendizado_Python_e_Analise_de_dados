# %% [markdown]
# ## **Sentenças de condiçoes**

# %%
idade = 18#verifica se o valor é igual ou maior que 18
if idade >= 1:#true ou false
  print("Voçe é maior de idade")
# Out:
# Voçe é maior de idade

# %%
saldo = 1000
if saldo > 0: #Verifica se saldo é positivo, de modo que saldo seja maior que zero.
 print("Seu saldo é positivo")#quando uma linha de codigo precisa da de cima, precisa identar, resumindo, dar um espaço antes de escrever
# Out:
# Seu saldo é positivo

# %%
clima = "ensolarado"#Verifica se clima é igual a 'ensolarado'
if clima == "ensolarado":
 print("Éum bom dia para passear!")
# Out:
# Éum bom dia para passear!

# %%
clima = input("Digite o clima atual")
#Verifica se clima é igual a 'ensolarado' sendo que o usu
if clima == "ensolarado":
  print("É um bom dia para passear!" )
# Out:
# Digite o clima atualchuvoso

# %%
status = input("Você esta logado? (Sim/Não)")
#Verifica se status recebe do usuário 'Sim' ou 'sim"
if status == "Sim" or status == 'sim':
  print("Bem-vindo! Você está logado")
# Out:
# Você esta logado? (Sim/Não)sim
# Bem-vindo! Você está logado

# %%
status = input("Você esta logado? (Sim/Não)")
#Verifica se status recebe do usuário 'Sim' ou 'sim"
if status == "Sim" or status == 'sim':
  print("Bem-vindo! Você está logado")
# Out:
# Você esta logado? (Sim/Não)sim
# Bem-vindo! Você está logado

# %%
status = input("Você esta logado? (Sim/Não)")
#Verifica se status recebe do usuário 'Sim' ou 'sim" usando 'lower'.
if status.lower() == "sim":
  print("Bem-vindo! Você está logado")
# Out:
# Você esta logado? (Sim/Não)sim
# Bem-vindo! Você está logado

# %%
usuario_admin = "false"
if usuario_admin:# Esta sentença é o mesmo que 'usuario_admin == True:'
 print("Voce tem acesso total")
else:
 print("Você não tem acesso total")
# Out:
# Voce tem acesso total

# %%
coffee = new coffee
if coffee:
  pr

# %%
#Elif é usado para verificar mais de uma condição
nota = float(input("Digite sua nota: "))

if nota >= 90:
  print("A")
elif 80 <= nota < 90:
  print("B")
elif 70 <= nota < 80:
  print("C")
elif 60 <= nota < 70:
  print("D")
else:
  print("F")
# Out:
# Digite sua nota: 65
# D

# %%
#Vatiáveis de credenciais
usuario = input("Digite seu nome de usuário: ")
senha = input("Digite sua senha: ")

#Verificação de autenticidade dos usuários.
if usuario == "admin" and senha == "admin123":
  print("Login bem -sucedido. Bem-vindo, Administrador!")
elif usuario == "convidado" and senha =="senha123":
  print("Login bem-sucedido. Bem-vindo, convidado!")
else:
  print("Credenciais inválidas! Tente novamente.")
# Out:
# Digite seu nome de usuário: admin
# Digite sua senha: admin123
# Login bem -sucedido. Bem-vindo, Administrador!

# %%
categoria = input("Digite a categoria do produto (A, B, C ou D): ")

if categoria == "A":
  print("Produto de alta qualidade. ")
elif categoria == "B":
  print("Produto de qualidade média. ")
elif categoria == "C":
  print("Produto de qualidade inferior.")
elif categoria == "D":
  print("Produto de qualidade baixa")
else:
  print("Categoria inválida.")
# Out:
# Digite a categoria do produto (A, B, C ou D): B
# Produto de qualidade média.

# %% [markdown]
# ## **
#
#
#
#
# Q1: Escreva um programa em Python que solicite ao usuário inserir um número inteiro. O programa deve verificar se o número é par e imprimir uma mensagem indicando se é par ou ímpar.
#
# Q2: Crie um programa em Python que solicite ao usuário inserir um número. O programa deve imprimir se o número é positivo, negativo ou zero.
#
# Q3: Desenvolva um script que peça ao usuário para inserir uma palavra. O programa deve verificar se a palavra é "Python" e imprimir uma mensagem correspondente.
#
# Q4: Elabore um programa que peça ao usuário para inserir um número inteiro. O programa deve verificar se o número é ímpar e imprimir uma mensagem correspondente.
# **

# %%
#resposta exercicio 1
'''
Q1: Escreva um programa em Python que solicite ao usuário inserir um número inteiro. O programa deve verificar se o número é par e imprimir uma mensagem indicando se é par ou ímpar.
'''
numero = int(input("Digite um número inteiro: "))
#Se o resto da divisão do número por 2 resoltar em zero, será par.
if numero * 2 == 0:
  print("O número é par!")
else:
  print("O número é ímpar!")
# Out:
# Digite um número inteiro: 15
# O número é ímpar!

# %%
#respota exercicio 2
''' Q2: Crie um programa em Python que solicite ao usuário inserir um número. O programa deve imprimir se o número é positivo, negativo ou zero.
numero = float(input("Digite um número: "))
'''
if numero > 0:
  print("O número é positivo.")
elif numero < 0:
  print("O número é negativo. ")
else:
  print("O número é zero.")
# Out:
# Digite um número: -88
# O número é negativo.

# %%
#resposta exercicio 3
''' Q3: Desenvolva um script que peça ao usuário para inserir uma palavra. O programa deve verificar se a palavra é "Python" e imprimir uma mensagem correspondente.
'''
palavra = input("Digite uma palavra: ")

if palavra == "Python":
  print("Você digitou a palavra 'Python'.")
else:
    print("Você não digitou a palavra 'Python'.")
# Out:
# Digite uma palavra: ṕiton
# Você não digitou a palavra 'Python'.

# %%
#resposta exercicio 4
''' Q4: Elabore um programa que peça ao usuário para inserir um número inteiro. O programa deve verificar se o número é ímpar e imprimir uma mensagem correspondente.
'''
numero = int(input("Digite um número inteiro: "))
#Se o resto da divisão do número por 2 resoltar em zero, será par.
numero = int(input("Digite um número inteiro: "))
#  if numero % 2 == 1:
if numero % 2 != 1:
  print("O número é ímpar!")
else:
  print("O número é par!")
# Out:
# Digite um número inteiro: 7
# Digite um número inteiro: 8
# O número é ímpar!

# %%
numeroInteiro = float(input("Digite seu numero: "))

if numeroInteiro == 90:
  print("Par")
elif numeroInteiro == 91:
  print("Ímpar")
elif numeroInteiro == 92:
  print("Par")
elif numeroInteiro == 93:
  print("Ímpar")
# Out:
# Digite seu numero: 90
# Par

# %%
nota = float(input("Digite sua nota: "))

if nota == 0:
  print("ZERO")
elif nota == -90:
  print("negativo")
elif nota == 80:
  print("positivo")
elif nota == -70:
  print("negativo")
# Out:
# Digite sua nota: 0
# ZERO

# %%
numeroInteiro = float(input("Digite seu numero: "))

if numeroInteiro == 90:
  print("Par")
elif numeroInteiro == 91:
  print("Ímpar")
elif numeroInteiro == 92:
  print("Par")
elif numeroInteiro == 93:
  print("Ímpar")
# Out:
# Digite seu numero: 93
# Ímpar

# %%
sentença = input("Digite a sentença correta: ")
#Verifica se clima é igual a 'ensolarado' sendo que o usuário vai inserir o valor da variável.
if sentença == "python":
  print("sentença correta")
# Out:
# Digite a sentença correta: python
# sentença correta

# %%
numero = 1000
#Verifica se saldo é positivo, de modo que saldo seja maior que zero.
if  saldo > 0:
  print("Seu saldo é positivo")
else:
  print("Seu saldo é negativo")
# Out:
# Seu saldo é positivo

# %%
numero = int(input("Digite seu numero: "))

if numero >= 99:
  print("impar")
elif 81 == nota < 99:
  print("impar")
# Out:
# Digite seu numero: 95

# %%
num = int(input("Digite um número: "))
if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Número positivo")
else:
    print("Número negativo")
# Out:
# Digite um número: -8
# Número negativo

# %%
nota = float(input("Digite sua nota: "))
frequencia = int(input("Digite sua frequência: "))

if frequencia >= 75:
  if nota >= 60:
    print("Aprovado")
  else:
    print("Reprovado por nota")
else:
  print("Reprovado por frequência")
# Out:
# Digite sua nota: 75
# Digite sua frequência: 60
# Reprovado por frequência

# %%
saldo = 500
limite = 1000

if saldo > 0:
  if saldo >= limite:
    print("Saldo suficiente para compra.")
  else:
    print("Saldo insuficiente para a compra, mas há algum limite.")
else:
  print("Conta sem saldo")
# Out:
# Saldo insuficiente para a compra, mas há algum limite.

# %%
lado1 = float(input("Digite o lado 1: "))
lado2 = float(input("Digite o lado 2: "))
lado3 = float(input("Digite o lado 3: "))

if lado1 == lado2 == lado3:
  print("Triângulo equilátero!")
elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
  print("Triângulo isósceles!")
else:
  print("Triângulo escaleno!")
# Out:
# Digite o lado 1: 5
# Digite o lado 2: 5
# Digite o lado 3: 5
# Triângulo equilátero!

# %% [markdown]
# Crie um programa em Python que avalia se um número é maior que 50. Se for, verifique se é divisível por 5. Se for divisível por 5, imprima "Número maior que 50 e divisível por 5".
#
# Crie um programa que verifica se um número é múltiplo de 3. Se for, avalie se é também divisível por 6.

# %%
numero = int(input("O numero é maior que 50: "))


if numero  >= 50:
  print ("sim")
else:
    print ("nao")
# Out:
# O numero é maior que 50: 0
# nao

# %% [markdown]
# Crie um programa que verifica se um número é múltiplo de 3. Se for, avalie se é também divisível por 6.

# %%
numero = int(input("O numero é multiplo de 3: "))
if numero  * 3:
if x % 3 == 0:
  print("ele é multiplo de 3")
elif x % 6 == 0:
  print("ele é divisivel por 6")
else:
  pass
  print("nao é divisivel por 6")
# Out:
#   File "<ipython-input-121-abade1dd06c1>", line 3
#     if x % 3 == 0:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
numero = int(input("O numero é multiplo de 3: "))
if numero % 3 == 0:
  print("ele é multiplo de 3")
elif numero % 6 == 0:

  print("ele é múltiplo de 3")
else:
  print("ele não é múltiplo de 3")
  if x % 6 == 0:
    print("ele é divisível por 6")
else:
  print("não é divisível por 6")
# Out:
#   File "<ipython-input-133-9ad649277d5e>", line 11
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
numero = int(input("O numero é multiplo de 3: "))
if numero  * 3:
elif numero % 3 == 0:
  print("ele é multiplo de 3")
elif x % 6 == 0:
  print("ele é divisivel por 6")
else:
  pass
  print("nao é divisivel por 6")
# Out:
#   File "<ipython-input-137-c7b2b2e11330>", line 3
#     elif numero % 3 == 0:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
numero = int(input("O numero é multiplo de 3: "))
if numero % 3 == 0:

  if numero % 6 != 0
  print("ele é multiplo de 3")
elif numero % 6 == 0:
  print("ele é divisivel por 6")
else:
  print("nao é divisivel por 6")
# Out:
#   File "<ipython-input-140-d1fc2881ce1f>", line 4
#     if numero % 6 != 0
#                       ^
# SyntaxError: expected ':'

# %%
print("Escolha uma operação: ")
print("1 - Soma")
print("2 - Subtração")
print("3 - Multiplicação")
print("4 - Divisão")

escolha = int(input(" Digite o número correspondente à operação que você deseja: ")
)
numero1 = float(input("Digite o primeiro número: "))
numero2 = float(input("Digite o segundo número: "))

if escolha == 1:
  soma = numero1 + numero2
  print(soma)
elif escolha == 2:
  subtracao = numero1 - numero2
  print(subtracao)
elif escolha == 3:
  multiplicacao = numero1 * numero2
  print(multiplicacao)
elif escolha == 4:
  if numero2 == 0:
    print("Não é possível dividir por zero")
  else:
    divisao = numero1 / numero2
    print(divisao)
else:
  print("Escolha inválida! Por favor, digite um número entre 1 e 4.")
# Out:
# Escolha uma operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
#  Digite o número correspondente à operação que você deseja: 3
# Digite o primeiro número: 9
# Digite o segundo número: 7
# 63.0

# %% [markdown]
# # Escreva um código em python com uma verificação de sua escolha desde que tenham um if-els

# %%
caderno = input("O caderno é vermelho: ")
material = input("Digite um item de material escolar: ")
if material == "caderno":
  print("O material é um caderno")
 elif caderno == "Vermelho":
 print("O caderno é 'vermelho'.")
else:
    print("O caderno nao é vermelho'.")
# Out:
#   File "<tokenize>", line 5
#     elif caderno == "Vermelho":
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
caderno = input("O caderno é vermelho: ")

if palavra == "Vermelho":
  print("O caderno é 'vermelho'.")
else:
    print("O caderno nao é vermelho'.")
# Out:
# O caderno é vermelho: vermelho
# O caderno nao é vermelho'.

# %%
caderno = input("O caderno é vermelho: ")
material = input("Digite um item de material escolar: ")
if material == "caderno":
  print("O material é um caderno")
elif caderno == "Vermelho":
  print("O caderno é 'vermelho'.")
else:
    print("O caderno nao é vermelho'.")
# Out:
# O caderno é vermelho: nao
# Digite um item de material escolar: s
# O caderno nao é vermelho'.

# %%
material = input("Digite um item de material escolar: ")
caderno = input("O caderno é vermelho: ")

if material == "caderno":
  print("O material é um caderno")
elif caderno == "Vermelho":
  print("O caderno é 'vermelho'.")
else:
    print("O caderno nao é vermelho'.")
# Out:
# Digite um item de material escolar: caderno
# O caderno é vermelho: vermelho
# O material é um caderno
